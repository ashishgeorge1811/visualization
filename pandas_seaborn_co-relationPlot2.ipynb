# %%
# For reading data set
# importing necessary libraries
import pandas as pd 
import numpy as np
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
# filtering of warnings
import warnings
warnings.filterwarnings('ignore')
# data visualization
# %matplotlib inline

# %%
# loading the data
cars = pd.read_csv("C:\\Users\\ashish\\Desktop\\python\\python\\data_sets\\Cars.csv")
#mtcars = pd.read_csv('Cars.csv')
#mtcars.head()
cars.head()
#cars.shape
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
 cars[(cars.VOL>100) & (cars.HP>90)] 
#print(d)
#cars2.head()

#cars2.shape
# Out:
#      HP        MPG  VOL          SP         WT
# 22   95  38.310606  101  120.288996  32.675828
# 26   92  38.411003  117  120.760520  38.062823
# 29  103  35.404192  107  121.840817  35.549360
# 33  102  36.285456  113  121.392639  37.573290
# 40   95  35.152727  113  116.392639  37.392524
# 41   95  35.152727  106  115.748847  35.027176
# 44   93  35.643558  102  114.380966  33.078632
# 46  100  34.561499  111  118.208698  36.498617
# 47   98  35.052330  103  116.472936  33.910056
# 49  115  29.629936  101  118.288996  33.458472
# 50  115  29.629936  101  118.288996  33.213954
# 51  115  29.629936  101  118.288996  33.436711
# 52  115  29.629936  124  120.404312  40.398164
# 53  180  24.487367  113  143.392639  37.620695
# 54  160  26.852279  113  135.392639  37.254392
# 55  130  27.856252  124  126.404312  40.589068
# 57  115  29.629936  101  118.288996  32.734518
# 59  100  28.860225  115  115.576579  37.662874
# 60  145  27.354265  111  130.208698  36.888153
# ...

# %%
cars.columns
# Out:
# Index(['HP', 'MPG', 'VOL', 'SP', 'WT'], dtype='object')

# %% [markdown]
# ## pairplot

# %%
# Scatter plot between the variables along with histograms
import seaborn as sb
# pairplot
sb.pairplot(cars)

# %%
# Correlation matrix 
cars.corr() 
# we see there exists High collinearity between input variables especially between
# [Hp & SP] , [VOL,WT] so there exists collinearity problem
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
# dropping influential records
#cars = cars.drop(cars.index[0],axis=0)
#cars.shape
cars = cars.drop(cars.index[[70,76]],axis=0)
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# 5    70  45.696322   89  113.185353  29.591768
# 6    55  50.013401   92  105.461264  30.308480
# 7    62  46.716554   50  102.598513  15.847758
# 8    62  46.716554   50  102.598513  16.359484
# 9    80  42.299078   94  115.645204  30.920154
# 10   73  44.652834   89  111.185353  29.363341
# 11   92  39.354094   50  117.598513  15.753535
# 12   92  39.354094   99  122.105055  32.813592
# 13   73  44.652834   89  111.185353  29.378436
# 14   66  45.734893   89  108.185353  29.347279
# 15   73  44.652834   89  111.185353  29.604527
# 16   78  42.789909   91  114.369293  29.535784
# 17   92  39.354094   50  117.598513  16.194122
# 18   78  42.789909   91  114.369293  29.929394
# ...

# %%
columns = ['gender','length','diameter','height','wholeweight','shucked_weught','viseraWeight','shellweight','rings']

# %% [markdown]
# ## heatmap

# %%
import pandas as pd

ab = pd.read_csv('C:\\Users\\ashish\\Desktop\\python\\python\\data_sets\\abalone.data',names=columns)
ab.head()
# Out:
#   gender  length  diameter  height  wholeweight  shucked_weught  viseraWeight  \
# 0      M   0.455     0.365   0.095       0.5140          0.2245        0.1010
# 1      M   0.350     0.265   0.090       0.2255          0.0995        0.0485
# 2      F   0.530     0.420   0.135       0.6770          0.2565        0.1415
# 3      M   0.440     0.365   0.125       0.5160          0.2155        0.1140
# 4      I   0.330     0.255   0.080       0.2050          0.0895        0.0395
#
#    shellweight  rings
# 0        0.150     15
# 1        0.070      7
# 2        0.210      9
# 3        0.155     10
# 4        0.055      7

# %%
ab1 = pd.read_csv('C:\\Users\\ashish\\Desktop\\python\\python\\data_sets\\abalone.data',header =None)
ab1.head()
# Out:
#    0      1      2      3       4       5       6      7   8
# 0  M  0.455  0.365  0.095  0.5140  0.2245  0.1010  0.150  15
# 1  M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.070   7
# 2  F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.210   9
# 3  M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.155  10
# 4  I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.055   7

# %%
import seaborn as sb
# defining a function
def heatmap(df):
    #Create Correlation df    corr = df.corr()
    corr = df.corr()
    fig, ax = plt.subplots(figsize=(10,10))
    colormap = sb.diverging_palette(255, 20, as_cmap=True)
    sb.heatmap(corr, cmap=colormap, annot=True, fmt=".2f")
    plt.xticks(range(len(corr.columns)), corr.columns)   #Apply xticks
    plt.yticks(range(len(corr.columns)), corr.columns)     #Apply yticks
    print (len(corr.columns))
c = plt.show()   
   #show plot
    #Plot figsize

    # function calling 
heatmap(ab)
# Out:
# 8

# %% [markdown]
# # dealing with NuLL values

# %%
#Importing Data
claimants = pd.read_csv("C:\\Users\\Dell\\Desktop\\PHYTHON\\data_sets\\claimants.csv")
claimants
# Out:
#       CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0           5         0     0.0       1.0       0.0    50.0  34.940
# 1           3         1     1.0       0.0       0.0    18.0   0.891
# 2          66         1     0.0       1.0       0.0     5.0   0.330
# 3          70         0     0.0       1.0       1.0    31.0   0.037
# 4          96         1     0.0       1.0       0.0    30.0   0.038
# 5          97         0     1.0       1.0       0.0    35.0   0.309
# 6          10         0     0.0       1.0       0.0     9.0   3.538
# 7          36         0     1.0       1.0       0.0    34.0   4.881
# 8          51         1     1.0       1.0       0.0    60.0   0.874
# 9          55         1     0.0       1.0       0.0     NaN   0.350
# 10         61         0     1.0       1.0       0.0    37.0   6.190
# 11        148         0     0.0       1.0       0.0    41.0  19.610
# 12        150         1     0.0       1.0       0.0     7.0   1.678
# ...

# %%
claimants.shape
# Out:
# (1340, 7)

# %%
# view top 5 records in dataset
claimants.head()
# ATTORNEY is the target variable
# Out:
#    CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0        5         0     0.0       1.0       0.0    50.0  34.940
# 1        3         1     1.0       0.0       0.0    18.0   0.891
# 2       66         1     0.0       1.0       0.0     5.0   0.330
# 3       70         0     0.0       1.0       1.0    31.0   0.037
# 4       96         1     0.0       1.0       0.0    30.0   0.038

# %%
# removing CASENUM
f=claimants.drop(["LOSS"],axis=1) 
#claimants.drop(["CASENUM"],axis=1,inplace=True)

f.head()
# Out:
#    CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE
# 0        5         0     0.0       1.0       0.0    50.0
# 1        3         1     1.0       0.0       0.0    18.0
# 2       66         1     0.0       1.0       0.0     5.0
# 3       70         0     0.0       1.0       1.0    31.0
# 4       96         1     0.0       1.0       0.0    30.0

# %%
claimants.isnull().sum().index[1]
# Out:
# 'ATTORNEY'

# %%
# mean value for all columns using lambda
claimants.apply(lambda x:x.mean())
#claimants.apply(mean)
# Out:
# CASENUM     11202.001493
# ATTORNEY        0.488806
# CLMSEX          0.558735
# CLMINSUR        0.907621
# SEATBELT        0.017028
# CLMAGE         28.414422
# LOSS            3.806307
# dtype: float64

# %%
# will sum/count the number of NULL values
claimants.isnull().sum()
# Out:
# CASENUM       0
# ATTORNEY      0
# CLMSEX       12
# CLMINSUR     41
# SEATBELT     48
# CLMAGE      189
# LOSS          0
# dtype: int64

# %%
# gets you the most occuring value in ATTORNEY column
claimants.CLMAGE.value_counts()
#claimants.ATTORNEY.mode()
#claimants.CLMAGE.value_counts().index[0]
#claimants.CLMAGE.mode()
# Out:
# 10.0    61
# 40.0    55
# 6.0     46
# 30.0    45
# 8.0     45
# 0.0     45
# 9.0     42
# 7.0     41
# 5.0     32
# 50.0    30
# 11.0    30
# 39.0    29
# 33.0    27
# 19.0    27
# 34.0    26
# 16.0    26
# 35.0    24
# 38.0    24
# 43.0    24
# 37.0    23
# 41.0    23
# 17.0    22
# 13.0    22
# 49.0    21
# 15.0    21
# 36.0    20
# 48.0    18
# 44.0    18
# 31.0    17
# 14.0    16
#         ..
# 60.0    12
# 55.0    12
# 70.0    11
# 58.0     8
# 57.0     7
# 56.0     7
# 53.0     7
# 61.0     6
# 51.0     6
# 63.0     5
# 59.0     5
# 64.0     5
# 69.0     5
# 66.0     4
# 80.0     4
# 78.0     3
# 73.0     3
# 77.0     3
# 71.0     3
# 65.0     2
# 83.0     2
# 68.0     2
# 67.0     2
# 76.0     2
# 84.0     1
# 75.0     1
# 86.0     1
# 74.0     1
# 88.0     1
# 95.0     1
# Name: CLMAGE, Length: 68, dtype: int64

# %%
# filling the missing value with most occuring value    
claimants.iloc[:,0:1339] = claimants.iloc[:,0:1339].apply(lambda x:x.fillna(x.value_counts().index[0]))
claimants.isnull().sum()
#claimants.SEATBELT = claimants.SEATBELT.fillna(claimants.SEATBELT.value_counts().index[0])
# Out:
# CASENUM     0
# ATTORNEY    0
# CLMSEX      0
# CLMINSUR    0
# SEATBELT    0
# CLMAGE      0
# LOSS        0
# dtype: int64

# %%
# filling the missing values with the mean value of the column
claimants.CLMAGE = claimants.CLMAGE.fillna(claimants.CLMAGE.mean())
#claimants.CLMAGE = claimants.CLMAGE.fillna()
claimants.CLMAGE.head(100)
# Out:
# 0     50.0
# 1     18.0
# 2      5.0
# 3     31.0
# 4     30.0
# 5     35.0
# 6      9.0
# 7     34.0
# 8     60.0
# 9     10.0
# 10    37.0
# 11    41.0
# 12     7.0
# 13    40.0
# 14    37.0
# 15     9.0
# 16    58.0
# 17    58.0
# 18     3.0
# 19    38.0
# 20    37.0
# 21    39.0
# 22    38.0
# 23    30.0
# 24    54.0
# 25     3.0
# 26    61.0
# 27     0.0
# 28    40.0
# 29    10.0
#       ...
# 70    56.0
# 71    63.0
# 72    55.0
# 73    47.0
# 74     0.0
# 75     5.0
# 76    38.0
# 77    10.0
# 78    40.0
# 79    57.0
# 80    17.0
# 81     1.0
# 82    10.0
# 83    11.0
# 84    40.0
# 85    10.0
# 86    18.0
# 87    35.0
# 88    11.0
# 89    16.0
# 90    10.0
# 91     0.0
# 92     8.0
# 93    31.0
# 94    50.0
# 95    71.0
# 96    10.0
# 97     1.0
# 98    16.0
# 99     9.0
# Name: CLMAGE, Length: 100, dtype: float64
